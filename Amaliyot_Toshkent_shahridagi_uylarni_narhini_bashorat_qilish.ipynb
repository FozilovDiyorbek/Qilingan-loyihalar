# %% [markdown]
# <a href="https://colab.research.google.com/github/FozilovDiyorbek/Qilingan-loyihalar/blob/main/Amaliyot_Toshkent_shahridagi_uylarni_narhini_bashorat_qilish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Kerakli kutubhonalarni chaqirib olamiz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv')
df
# Out:
#                                                location           district  \
# 0     город Ташкент, Юнусабадский район, Юнусабад 8-...       Юнусабадский
# 1     город Ташкент, Яккасарайский район, 1-й тупик ...      Яккасарайский
# 2     город Ташкент, Чиланзарский район, Чиланзар 2-...       Чиланзарский
# 3     город Ташкент, Чиланзарский район, Чиланзар 9-...       Чиланзарский
# 4     город Ташкент, Чиланзарский район, площадь Актепа       Чиланзарский
# ...                                                 ...                ...
# 7560  город Ташкент, Яшнободский район, Городок Авиа...        Яшнободский
# 7561  город Ташкент, Яшнободский район, 1-й проезд А...        Яшнободский
# 7562  город Ташкент, Шайхантахурский район, Зульфиях...    Шайхантахурский
# 7563  город Ташкент, Мирзо-Улугбекский район, Буюк И...  Мирзо-Улугбекский
# 7564  город Ташкент, Чиланзарский район, Чиланзар 6-...       Чиланзарский
#
#       rooms size  level  max_levels  price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7565 entries, 0 to 7564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7565 non-null   object
#  1   district    7565 non-null   object
#  2   rooms       7565 non-null   int64
#  3   size        7565 non-null   object
#  4   level       7565 non-null   int64
#  5   max_levels  7565 non-null   int64
#  6   price       7565 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 413.8+ KB

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce').astype('Int64')### Dataset dagi bazi sonli ustunlarni object formatidan integer va float formatiga o'tkazish
df['size'] = pd.to_numeric(df['size'], errors='coerce').astype('float64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7565 entries, 0 to 7564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7565 non-null   object
#  1   district    7565 non-null   object
#  2   rooms       7565 non-null   int64
#  3   size        7564 non-null   float64
#  4   level       7565 non-null   int64
#  5   max_levels  7565 non-null   int64
#  6   price       7466 non-null   Int64
# dtypes: Int64(1), float64(1), int64(3), object(2)
# memory usage: 421.2+ KB

# %%
### Location ustuni kerak emas
house = df.drop('location', axis=1)
house
# Out:
#                district  rooms  size  level  max_levels  price
# 0          Юнусабадский      3  57.0      4           4  52000
# 1         Яккасарайский      2  52.0      4           5  56000
# 2          Чиланзарский      2  42.0      4           4  37000
# 3          Чиланзарский      3  65.0      1           4  49500
# 4          Чиланзарский      3  70.0      3           5  55000
# ...                 ...    ...   ...    ...         ...    ...
# 7560        Яшнободский      1  38.0      5           5  24500
# 7561        Яшнободский      2  49.0      1           4  32000
# 7562    Шайхантахурский      2  64.0      3           9  40000
# 7563  Мирзо-Улугбекский      1  18.0      1           4  11000
# 7564       Чиланзарский      1  30.0      2           4  22914
#
# [7565 rows x 6 columns]

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7465 entries, 0 to 7564
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   district    7465 non-null   object
#  1   rooms       7465 non-null   int64
#  2   size        7465 non-null   float64
#  3   level       7465 non-null   int64
#  4   max_levels  7465 non-null   int64
#  5   price       7465 non-null   Int64
# dtypes: Int64(1), float64(1), int64(3), object(1)
# memory usage: 415.5+ KB

# %%
### NaN qiymatlarni hammasini o'chirib yuborish
house.dropna(inplace=True)

# %%
house.describe()
# Out:
#              rooms          size        level   max_levels          price
# count  7465.000000   7465.000000  7465.000000  7465.000000         7465.0
# mean      2.622103    113.537018     3.693771     6.023979   71323.672472
# std       1.083155   1501.157996     2.236905     2.607103  640565.942591
# min       1.000000      1.000000     1.000000     1.000000            2.0
# 25%       2.000000     50.000000     2.000000     4.000000        35000.0
# 50%       3.000000     65.000000     3.000000     5.000000        46500.0
# 75%       3.000000     85.000000     5.000000     9.000000        67000.0
# max      10.000000  70000.000000    19.000000    25.000000     52000000.0

# %%
x_num = x_train.drop('district', axis=1)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(house, test_size=0.2, random_state=42)

# %%
x_train = train_set.drop('price', axis=1)
y = train_set['price'].copy()

# %%
y
# Out:
# 4552     37000
# 4450    210000
# 1656     27500
# 3570     46835
# 6618    140000
#          ...
# 5191     43500
# 5226     56000
# 5390     58500
# 860      53000
# 7270     50000
# Name: price, Length: 6052, dtype: Int64

# %%
y.mean()
# Out:
# 63219.28918285332

# %%
### Sonli ustunlar uchun pipeline qurib olamiz
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.pipeline import Pipeline

num_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

# %%
### Ful pipeline quramiz
from sklearn.compose import ColumnTransformer

num_attribs = list(x_num)
cat_attribs = ['district']

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OrdinalEncoder(), cat_attribs)
])

# %%
list(x_num)
# Out:
# ['rooms', 'size', 'level', 'max_levels']

# %%
###Logistik Regression modeli yordamida modelimizni o'qitib olamiz
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()

# %%
LR_model.fit(x_prepared, y)
# Out:
# LinearRegression()

# %%
test_set
# Out:
#              district  rooms   size  level  max_levels  price
# 2301      Яшнободский      3   86.0      4           9  89000
# 6126      Учтепинский      3   70.0      2           5  43500
# 2149    Яккасарайский      3   90.0      5           5  45000
# 5594     Чиланзарский      1   36.0      2           4  24700
# 6566      Учтепинский      4  100.0      1           4  87000
# ...               ...    ...    ...    ...         ...    ...
# 6593  Шайхантахурский      3   80.0      6           9  48000
# 4089  Шайхантахурский      6  500.0      2           2   1800
# 441      Чиланзарский      1   36.0      2           5  28500
# 5639  Шайхантахурский      3   70.0      6           7  60000
# 2538      Мирабадский      2   48.0      3           5  42000
#
# [1493 rows x 6 columns]

# %%
x_test = test_set.drop('price', axis=1)
y_test = test_set['price'].copy()

# %%
### modelni ishga tushurib test setimizni bashorat qilamiz
x_test_prepared = full_pipeline.transform(x_test)
x_test_prepared
# Out:
# array([[ 0.34611002, -0.01675774,  0.12524471,  1.11704692, 11.        ],
#        [ 0.34611002, -0.028128  , -0.75887042, -0.40150628,  5.        ],
#        [ 0.34611002, -0.01391517,  0.56730227, -0.40150628,  9.        ],
#        ...,
#        [-1.4952878 , -0.05228981, -0.75887042, -0.40150628,  6.        ],
#        [ 0.34611002, -0.028128  ,  1.00935984,  0.35777032,  7.        ],
#        [-0.57458889, -0.04376211, -0.31681286, -0.40150628,  1.        ]])

# %%
y_predicted = LR_model.predict(x_test_prepared)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae = mean_absolute_error(y_predicted, y_test)
mse = mean_squared_error(y_predicted, y_test)
print("MAE=", mae)
print("RMSE=", np.sqrt(mse))
# Out:
# MAE= 67639.75885299627
# RMSE= 1366181.8958744472

# %%
###Random Forest modeli yordamida modelimizni o'qitib olamiz
from sklearn.ensemble import RandomForestRegressor
RF_model = RandomForestRegressor()

RF_model.fit(x_prepared, y)
# Out:
# RandomForestRegressor()

# %%
y_predicted = RF_model.predict(x_test_prepared)

# %%
mae = mean_absolute_error(y_predicted, y_test)
mse = mean_squared_error(y_predicted, y_test)
print("MAE=", mae)
print("RMSE=", np.sqrt(mse))
# Out:
# MAE= 62930.253959273345
# RMSE= 1378397.4900662312
